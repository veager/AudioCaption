# %% [markdown]
# <a href="https://colab.research.google.com/github/veager/AudioCaption/blob/main/Codes/PyTorch-Tutorial/PyTorch-%E6%AD%A3%E5%88%99%E5%8C%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PyTorch-正则化.ipynb
#
# 参考资料：
#
# - 博客：PyTorch-正则化.ipynb，[地址](https://www.cnblogs.com/veager/articles/16305187.html)
#
# - GitHub：Codes/PyTorch-Tutorial/PyTorch-正则化.ipynb

# %% [markdown]
# # 0 加载数据

# %%
import time
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## 0.1 加载 Iris 数据集

# %%
from sklearn.datasets import load_diabetes
from sklearn.preprocessing import MinMaxScaler

data = load_diabetes()
X = data.data
Y = data.target

# 将输入输出数据归一化到 [0, 1] 之间
scaler_X = MinMaxScaler().fit(X)
scaler_Y = MinMaxScaler().fit(np.expand_dims(Y, axis=1))

Xs = scaler_X.transform(X)
Ys = scaler_Y.transform(np.expand_dims(Y, axis=1))

print(Xs.shape, Ys.shape)
print(Xs[:5], Ys[:5])
print(pd.DataFrame(Xs).describe(), pd.DataFrame(Ys).describe())

# 将数据转换为 tensor 类型 
Xs_tensor = torch.tensor(Xs, dtype=torch.float)
Ys_tensor = torch.tensor(Ys, dtype=torch.float)
# Out:
# (442, 10) (442, 1)
# [[0.66666667 1.         0.58264463 0.54929577 0.29411765 0.25697211
#   0.20779221 0.28208745 0.56221737 0.43939394]
#  [0.48333333 0.         0.14876033 0.35211268 0.42156863 0.30677291
#   0.62337662 0.14104372 0.22244301 0.16666667]
#  [0.88333333 1.         0.51652893 0.43661972 0.28921569 0.25896414
#   0.24675325 0.28208745 0.49658437 0.40909091]
#  [0.08333333 0.         0.30165289 0.30985915 0.49509804 0.44721116
#   0.23376623 0.42313117 0.57293604 0.46969697]
#  [0.51666667 0.         0.20661157 0.54929577 0.46568627 0.41733068
#   0.38961039 0.28208745 0.36236911 0.33333333]] [[0.39252336]
#  [0.15576324]
#  [0.36137072]
#  [0.56386293]
#  [0.34267913]]
#                 0           1           2           3           4           5  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean     0.491968    0.468326    0.346107    0.459818    0.451668    0.367725
# std      0.218484    0.499561    0.182567    0.194806    0.169647    0.151460
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.320833    0.000000    0.214876    0.309859    0.329657    0.271165
# 50%      0.516667    0.000000    0.318182    0.436620    0.436275    0.355578
# 75%      0.666667    1.000000    0.465909    0.605634    0.552696    0.462649
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6           7           8           9
# count  442.000000  442.000000  442.000000  442.000000
# mean     0.360889    0.291996    0.485557    0.503942
# std      0.167977    0.182010    0.183364    0.174187
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.237013    0.141044    0.357528    0.382576
# 50%      0.337662    0.282087    0.478057    0.500000
# 75%      0.464286    0.423131    0.610446    0.606061
# max      1.000000    1.000000    1.000000    1.000000                   0
# count  442.000000
# mean     0.396054
# std      0.240165
# min      0.000000
# 25%      0.193146
# 50%      0.359813
# 75%      0.580997
# max      1.000000

# %% [markdown]
# ## 0.2 全局参数设置

# %%
# 样本信息，划分的数据集
N_SAMPLE = Xs_tensor.size()[0]              # 样本总数
N_TRAIN = int(N_SAMPLE * 0.7)               # 训练样本数
N_VALID = int(N_SAMPLE * 0.2)               # 验证样本数
N_TEST = N_SAMPLE - N_TRAIN - N_VALID       # 测试样本数


# 训练过程超参数设置
BATCH_SIZE = 64
N_EPOCH = 1000
LEARNING_RATE = 0.05


# 神经网络模型参数
HIDDEN_DIM = 4
INPUT_DIM = Xs_tensor.size()[1]     # sizes of input data and output data
OUTPUT_DIM = Ys_tensor.size()[1]
print("NN Structure:", INPUT_DIM, HIDDEN_DIM, OUTPUT_DIM)


# 设置 device，如果 GPU 可用，则使用
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print("device:", DEVICE)
# Out:
# NN Structure: 10 4 1
# device: cuda:0

# %% [markdown]
# ## 0.3 创建结构化数据

# %%
from torch.utils.data import TensorDataset, Dataset, random_split, DataLoader
from torch.utils.data.dataloader import default_collate

# DataSet 类
ds = TensorDataset(Xs_tensor, Ys_tensor)

# split training, validation, testing data
ds_train, ds_vaild, ds_test = random_split(ds, lengths=[N_TRAIN, N_VALID, N_TEST])
print(len(ds_train), len(ds_vaild), len(ds_test))


# DataLoader of train data, valid data, test data
dl_train = DataLoader(ds_train, batch_size = BATCH_SIZE, shuffle = True,
    collate_fn = lambda x: tuple(x_.to(DEVICE) for x_ in default_collate(x))
    )

dl_valid = DataLoader(ds_vaild, batch_size = BATCH_SIZE, # default shuffle = False,
    collate_fn = lambda x: tuple(x_.to(DEVICE) for x_ in default_collate(x))
    )

dl_test = DataLoader(ds_test, batch_size = BATCH_SIZE, # default shuffle = False,
    collate_fn = lambda x: tuple(x_.to(DEVICE) for x_ in default_collate(x))
    )
# Out:
# 309 88 45

# %% [markdown]
# ## 0.4 定义模型

# %%
# 方式 2: 全部使用 层类（nn.Module 类）
class BPNNModeler2(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):

        super(BPNNModeler2, self).__init__()

        # Layer 1
        self.layer1_linear = nn.Linear(input_dim, hidden_dim)
        self.layer1_sigmoid = nn.Sigmoid()
        # Layer 2
        self.layer2_linear = nn.Linear(hidden_dim, output_dim)
        self.layer2_sigmoid = nn.Sigmoid()
        # Output
        self.layer2_flattern = nn.Flatten(0, -1)
    
    # 正向传播
    def forward(self, x):
        # Layer 1
        out_layer1 = self.layer1_linear(x)
        out_layer1 = self.layer1_sigmoid(out_layer1)
        # Layer 2
        out_layer2 = self.layer2_linear(out_layer1)
        out_layer2 = self.layer2_sigmoid(out_layer2)
        # Output
        out = self.layer2_flattern(out_layer2)
        return out
# ==============================================================================

# %% [markdown]
# ### 0.4.1 初始化模型

# %%
# 定义模型
model = BPNNModeler2(input_dim = INPUT_DIM, hidden_dim = HIDDEN_DIM, output_dim = OUTPUT_DIM)
model = model.to(DEVICE)

# %% [markdown]
# ## 0.5 定义损失函数

# %%
# 定义 损失函数 MSE 损失
def loss_func(model_out, target, reduction='mean'):
    loss = F.mse_loss(model_out, target, reduction=reduction) 
    return loss

# %% [markdown]
# # 1 正则化

# %% [markdown]
# ## 1.1 权重衰减 Weight Decay

# %% [markdown]
# ## 1.2 L1 和 L2 正则化

# %% [markdown]
# 定义正则化函数

# %%
def regularization_loss(model, factor, p=2):
    '''
    regularization_loss，只惩罚含有 weight 的参数
    model: 传入模型
    factor: 正则化惩罚系数
    p: p-范数
    '''
    reg_loss = torch.tensor(0.)

    for name, w in model.named_parameters():
        print(w.requires_grad)
        if 'weight' in name:    # 只对 参数名 含有 weight 的参数 正则化
            reg_loss = reg_loss + torch.norm(w, p)
    
    reg_loss = factor * reg_loss
    return reg_loss

# %%
N_EPOCH = 100
LEARNING_RATE = 0.01

# Step 1: 定义优化器
optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE)

for epoch in range(N_EPOCH):

    train_total_loss = 0.
    fun_total_loss = 0.
    reg_total_loss = 0.

    for i, (X_batch, Y_batch) in enumerate(dl_train): 

        optimizer.zero_grad()    # Step 2: 参数梯度归零

        out = model(X_batch)  

        fun_loss = loss_func(out, Y_batch.flatten(), reduction='sum')  # 函数损失
        reg_loss = regularization_loss(model, factor=0.1)  # 正则化损失
        print(reg_loss.requires_grad)
        train_loss = fun_loss + reg_loss       # 总损失

        train_loss.backward()    # Step 3: 反向传播，计算梯度
        optimizer.step()         # Step 4: 执行一步优化，更新参数

        fun_total_loss += fun_loss.item()
        reg_total_loss += reg_loss.item()
        train_total_loss += train_loss.item()

    if (epoch + 1) % 1 == 0:
        # Print Traing information
        print('Epoch: {0:>4}, Loss: {1:>10.5f}, Reg Loss: {2:>10.8f}, Total Loss: {3:>10.8f}'.format(
            epoch+1, 
            fun_total_loss, 
            reg_total_loss, 
            train_total_loss))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:    1, Loss:    8.60657, Reg Loss: 3.31027704, Total Loss: 11.91684401
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:    2, Loss:    8.60537, Reg Loss: 3.30920142, Total Loss: 11.91457534
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:    3, Loss:    8.61193, Reg Loss: 3.31001467, Total Loss: 11.92194891
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:    4, Loss:    8.59119, Reg Loss: 3.30975384, Total Loss: 11.90093935
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:    5, Loss:    8.63322, Reg Loss: 3.31041163, Total Loss: 11.94362748
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:    6, Loss:    8.57188, Reg Loss: 3.30963016, Total Loss: 11.88150811
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:    7, Loss:    8.59021, Reg Loss: 3.31112766, Total Loss: 11.90133929
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:    8, Loss:    8.57168, Reg Loss: 3.31112075, Total Loss: 11.88280094
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:    9, Loss:    8.58180, Reg Loss: 3.31201649, Total Loss: 11.89381337
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   10, Loss:    8.59148, Reg Loss: 3.31075817, Total Loss: 11.90224075
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   11, Loss:    8.57648, Reg Loss: 3.31286007, Total Loss: 11.88933897
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   12, Loss:    8.60009, Reg Loss: 3.31198484, Total Loss: 11.91207647
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   13, Loss:    8.57303, Reg Loss: 3.31354624, Total Loss: 11.88658094
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   14, Loss:    8.58112, Reg Loss: 3.31206691, Total Loss: 11.89318585
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   15, Loss:    8.57397, Reg Loss: 3.31469762, Total Loss: 11.88867259
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   16, Loss:    8.61199, Reg Loss: 3.31440216, Total Loss: 11.92639613
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   17, Loss:    8.58464, Reg Loss: 3.31391817, Total Loss: 11.89856339
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   18, Loss:    8.56718, Reg Loss: 3.31352776, Total Loss: 11.88071024
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   19, Loss:    8.61865, Reg Loss: 3.31347656, Total Loss: 11.93213153
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   20, Loss:    8.56850, Reg Loss: 3.31383926, Total Loss: 11.88234305
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   21, Loss:    8.58359, Reg Loss: 3.31648749, Total Loss: 11.90007925
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   22, Loss:    8.59802, Reg Loss: 3.31496829, Total Loss: 11.91298556
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   23, Loss:    8.59366, Reg Loss: 3.31429732, Total Loss: 11.90795350
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   24, Loss:    8.55800, Reg Loss: 3.31566870, Total Loss: 11.87366652
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   25, Loss:    8.56932, Reg Loss: 3.31491739, Total Loss: 11.88423538
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   26, Loss:    8.56879, Reg Loss: 3.31587344, Total Loss: 11.88466716
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   27, Loss:    8.56136, Reg Loss: 3.31569445, Total Loss: 11.87705612
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   28, Loss:    8.56534, Reg Loss: 3.31745303, Total Loss: 11.88279366
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   29, Loss:    8.58372, Reg Loss: 3.31586647, Total Loss: 11.89958167
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   30, Loss:    8.56391, Reg Loss: 3.31716710, Total Loss: 11.88107252
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   31, Loss:    8.59162, Reg Loss: 3.31776005, Total Loss: 11.90938473
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   32, Loss:    8.63533, Reg Loss: 3.31697941, Total Loss: 11.95231223
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   33, Loss:    8.59357, Reg Loss: 3.31791818, Total Loss: 11.91149139
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   34, Loss:    8.56056, Reg Loss: 3.31825608, Total Loss: 11.87882090
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   35, Loss:    8.56287, Reg Loss: 3.31656587, Total Loss: 11.87943101
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   36, Loss:    8.59098, Reg Loss: 3.31852937, Total Loss: 11.90950584
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   37, Loss:    8.61829, Reg Loss: 3.31795686, Total Loss: 11.93624806
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   38, Loss:    8.58199, Reg Loss: 3.31924808, Total Loss: 11.90124106
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   39, Loss:    8.57479, Reg Loss: 3.32030261, Total Loss: 11.89509201
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   40, Loss:    8.56151, Reg Loss: 3.31774640, Total Loss: 11.87925291
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   41, Loss:    8.55727, Reg Loss: 3.31998324, Total Loss: 11.87725306
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   42, Loss:    8.55369, Reg Loss: 3.31860685, Total Loss: 11.87229538
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   43, Loss:    8.58555, Reg Loss: 3.32042843, Total Loss: 11.90598154
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   44, Loss:    8.55898, Reg Loss: 3.32104772, Total Loss: 11.88002968
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   45, Loss:    8.55592, Reg Loss: 3.32027858, Total Loss: 11.87619841
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   46, Loss:    8.62574, Reg Loss: 3.32006657, Total Loss: 11.94581079
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   47, Loss:    8.58414, Reg Loss: 3.32210100, Total Loss: 11.90624428
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   48, Loss:    8.57621, Reg Loss: 3.32063049, Total Loss: 11.89684463
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   49, Loss:    8.57410, Reg Loss: 3.32053739, Total Loss: 11.89463830
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   50, Loss:    8.57801, Reg Loss: 3.32069445, Total Loss: 11.89870572
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   51, Loss:    8.55453, Reg Loss: 3.32067293, Total Loss: 11.87520766
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   52, Loss:    8.55104, Reg Loss: 3.32203692, Total Loss: 11.87307930
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   53, Loss:    8.56011, Reg Loss: 3.32250661, Total Loss: 11.88262010
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   54, Loss:    8.57576, Reg Loss: 3.32208228, Total Loss: 11.89784050
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   55, Loss:    8.54782, Reg Loss: 3.32107776, Total Loss: 11.86889529
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   56, Loss:    8.57892, Reg Loss: 3.32168180, Total Loss: 11.90059888
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   57, Loss:    8.55279, Reg Loss: 3.32291704, Total Loss: 11.87570810
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   58, Loss:    8.64857, Reg Loss: 3.32232511, Total Loss: 11.97089839
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   59, Loss:    8.56313, Reg Loss: 3.32248235, Total Loss: 11.88561273
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   60, Loss:    8.57257, Reg Loss: 3.32260323, Total Loss: 11.89517140
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   61, Loss:    8.55579, Reg Loss: 3.32369655, Total Loss: 11.87948775
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   62, Loss:    8.54606, Reg Loss: 3.32396597, Total Loss: 11.87002444
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   63, Loss:    8.56391, Reg Loss: 3.32258624, Total Loss: 11.88649607
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   64, Loss:    8.55967, Reg Loss: 3.32197022, Total Loss: 11.88164139
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   65, Loss:    8.55931, Reg Loss: 3.32436126, Total Loss: 11.88367105
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   66, Loss:    8.55366, Reg Loss: 3.32406837, Total Loss: 11.87772989
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   67, Loss:    8.57411, Reg Loss: 3.32406741, Total Loss: 11.89817882
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   68, Loss:    8.54796, Reg Loss: 3.32298839, Total Loss: 11.87095332
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   69, Loss:    8.56421, Reg Loss: 3.32499385, Total Loss: 11.88920307
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   70, Loss:    8.54907, Reg Loss: 3.32454216, Total Loss: 11.87361336
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   71, Loss:    8.54417, Reg Loss: 3.32511377, Total Loss: 11.86928582
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   72, Loss:    8.56612, Reg Loss: 3.32464159, Total Loss: 11.89075899
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   73, Loss:    8.56083, Reg Loss: 3.32393473, Total Loss: 11.88476276
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   74, Loss:    8.56305, Reg Loss: 3.32547796, Total Loss: 11.88852668
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   75, Loss:    8.56849, Reg Loss: 3.32504934, Total Loss: 11.89353442
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   76, Loss:    8.56544, Reg Loss: 3.32610703, Total Loss: 11.89154768
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   77, Loss:    8.53882, Reg Loss: 3.32465690, Total Loss: 11.86347580
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   78, Loss:    8.56598, Reg Loss: 3.32708889, Total Loss: 11.89306426
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   79, Loss:    8.54682, Reg Loss: 3.32480067, Total Loss: 11.87161851
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   80, Loss:    8.55183, Reg Loss: 3.32643884, Total Loss: 11.87826538
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   81, Loss:    8.58598, Reg Loss: 3.32389897, Total Loss: 11.90987682
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   82, Loss:    8.54345, Reg Loss: 3.32625568, Total Loss: 11.86970139
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   83, Loss:    8.61007, Reg Loss: 3.32630569, Total Loss: 11.93637872
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   84, Loss:    8.56907, Reg Loss: 3.32628691, Total Loss: 11.89535975
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   85, Loss:    8.53859, Reg Loss: 3.32524580, Total Loss: 11.86383796
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   86, Loss:    8.57088, Reg Loss: 3.32815534, Total Loss: 11.89903092
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   87, Loss:    8.55206, Reg Loss: 3.32646763, Total Loss: 11.87852907
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   88, Loss:    8.56986, Reg Loss: 3.32620996, Total Loss: 11.89606643
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   89, Loss:    8.53753, Reg Loss: 3.32713354, Total Loss: 11.86466408
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   90, Loss:    8.54101, Reg Loss: 3.32679981, Total Loss: 11.86781073
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   91, Loss:    8.55013, Reg Loss: 3.32672262, Total Loss: 11.87685680
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   92, Loss:    8.58187, Reg Loss: 3.32659930, Total Loss: 11.90846467
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   93, Loss:    8.59893, Reg Loss: 3.32806104, Total Loss: 11.92699313
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   94, Loss:    8.54936, Reg Loss: 3.32510215, Total Loss: 11.87446117
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   95, Loss:    8.53795, Reg Loss: 3.32965976, Total Loss: 11.86761355
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   96, Loss:    8.54186, Reg Loss: 3.32758629, Total Loss: 11.86945057
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   97, Loss:    8.56219, Reg Loss: 3.32759744, Total Loss: 11.88978457
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   98, Loss:    8.55541, Reg Loss: 3.32766169, Total Loss: 11.88307571
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:   99, Loss:    8.54524, Reg Loss: 3.32695621, Total Loss: 11.87219501
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Epoch:  100, Loss:    8.53065, Reg Loss: 3.32823372, Total Loss: 11.85888124
